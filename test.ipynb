# %% [markdown]
# # **Testing the Asian Card Games**

# %%
from games.pok.pok import Pok

game = Pok(num_players=4)
game.deal_cards()
game.players
# Out:
# {'Player 1': Player 1's hand: [9 of HEARTS, ACE of CLUBS],
#  'Player 2': Player 2's hand: [3 of SPADES, 6 of CLUBS],
#  'Player 3': Player 3's hand: [2 of SPADES, ACE of DIAMONDS],
#  'Player 4': Player 4's hand: [5 of DIAMONDS, 8 of SPADES]}

# %%
game.players['Player 1'].hand
# Out:
# [9 of HEARTS, ACE of CLUBS]

# %%
from games.pok.logic import calculate_score
calculate_score(game.players['Player 1'].hand)
# Out:
# {'score': 0,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}
