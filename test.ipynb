# %%
from cards.cards import Deck

deck = Deck()
print(deck)
# Out:
# Deck is shuffled with ID of pndkqsa7b8dz and 52 cards remaining.

# %%
card = deck.draw_cards(1)
# Out:
# 'QUEEN'

# %%
cards = deck.draw_cards(6)
for card in cards:
    print(card)
# Out:
# ACE of CLUBS
# ACE of SPADES
# QUEEN of DIAMONDS
# 6 of CLUBS
# KING of SPADES
# 4 of SPADES

# %%
cards
# Out:
# [<cards.cards.Card at 0x109b631d0>,
#  <cards.cards.Card at 0x109b63200>,
#  <cards.cards.Card at 0x109b63230>,
#  <cards.cards.Card at 0x109b63260>,
#  <cards.cards.Card at 0x109b63290>,
#  <cards.cards.Card at 0x109b632c0>]

# %%
deck.remaining
# Out:
# 46

# %%
from cards.visualize import visualize_cards

visualize_cards(cards, 2, 3)

# %%
def arrange_ongdu(cards):
    first_set, second_set = [], []
    for i, card in enumerate(cards):
        if i < len(cards) / 2:
            first_set.append(card)
        else:
            second_set.append(card)
    return first_set, second_set

# %%
arrange_ongdu(cards)
# Out:
# ([<cards.cards.Card at 0x109b631d0>,
#   <cards.cards.Card at 0x109b63200>,
#   <cards.cards.Card at 0x109b63230>],
#  [<cards.cards.Card at 0x109b63260>,
#   <cards.cards.Card at 0x109b63290>,
#   <cards.cards.Card at 0x109b632c0>])

# %%
from games.pok.pok import Pok

pok = Pok(2)
game = pok.start()
game
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from games.pok.pok import Pok
#       3 pok = Pok(2)
# ----> 4 game = pok.start()
#       5 game
#
# File ~/Documents/Projects/asian-cards/games/pok/pok.py:70, in Pok.start(self)
#      68 def start(self):
#      69     self.deal_cards()
# ---> 70     self.player_turns()
#      71     self.dealer_turn()
#      72     return {"Players": self.players, "Dealer": self.dealer_hand}
#
# File ~/Documents/Projects/asian-cards/games/pok/pok.py:60, in Pok.player_turns(self)
#      58 score = self.calculate_score(player.hand)["score"]
#      59 if score < 4:
# ---> 60     self.draw_card(player.name)
#
# File ~/Documents/Projects/asian-cards/games/pok/pok.py:52, in Pok.draw_card(self, player_name)
#      50 def draw_card(self, player_name):
#      51     if self.players[player_name].can_draw:
# ---> 52         card = self.deck.draw_cards(1)['cards'][0]
#      53         self.players[player_name].draw_card(card)
#
# TypeError: 'Card' object is not subscriptable

# %%
from cards.visualize import visualize_cards
visualize_cards(game["Dealer"], rows=1, cols=2)

# %%
pok.deck.remaining
# Out:
# 46

# %%
pok.players
# Out:
# {'Player 1': <games.pok.pok.Player at 0x1107ef0b0>,
#  'Player 2': <games.pok.pok.Player at 0x110f4a270>}

# %%
pok.dealer_hand
# Out:
# [<cards.cards.Card at 0x11485fe90>, <cards.cards.Card at 0x11485fb90>]

# %%
pok.deck.remaining
# Out:
# 46

# %%
pok.calculate_score(pok.dealer_hand)
# Out:
# 7
