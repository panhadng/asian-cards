# %%
from cards.cards import Deck

deck = Deck()
print(deck)
# Out:
# Deck is shuffled with ID of m5qy02634hbn and 52 cards remaining.

# %%
card = deck.draw_cards(1)
print(card)
# Out:
# 3 of CLUBS

# %%
deck.remaining
# Out:
# 51

# %%
cards = deck.draw_cards(6)
for card in cards:
    print(card)
# Out:
# 4 of CLUBS
# 6 of SPADES
# 9 of SPADES
# JACK of SPADES
# 3 of HEARTS
# 5 of SPADES

# %%
cards
# Out:
# [<cards.cards.Card at 0x10faedb20>,
#  <cards.cards.Card at 0x10faedb50>,
#  <cards.cards.Card at 0x10faedb80>,
#  <cards.cards.Card at 0x10faedbb0>,
#  <cards.cards.Card at 0x10faedbe0>,
#  <cards.cards.Card at 0x10faedc10>]

# %%
deck.remaining
# Out:
# 45

# %%
from cards.visualize import visualize_cards

visualize_cards(cards, rows=2, cols=3)

# %%
from games.pok.pok import Pok

pok = Pok(num_players=2)
game = pok.start()
game
# Out:
# {'Players': {'Player 1': <games.pok.pok.Player at 0x10fad3140>,
#   'Player 2': <games.pok.pok.Player at 0x12a832750>},
#  'Dealer': [<cards.cards.Card at 0x12a9058e0>,
#   <cards.cards.Card at 0x12a904a10>]}

# %%
pok.players
# Out:
# {'Player 1': <games.pok.pok.Player at 0x10fad3140>,
#  'Player 2': <games.pok.pok.Player at 0x12a832750>}

# %%
pok.dealer

# %%
from cards.visualize import visualize_cards
visualize_cards(game["Dealer"], rows=1, cols=2)

# %%
for card in pok.dealer.hand:
    print(card)
# Out:
# 5 of CLUBS
# 5 of HEARTS

# %%
pok.calculate_score(pok.dealer.hand)
# Out:
# {'score': 0,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}

# %%
pok.draw_card("Dealer")

# %%
for card in pok.dealer.hand:
    print(card)
# Out:
# 5 of CLUBS
# 5 of HEARTS
# 9 of CLUBS

# %%
pok.calculate_score(pok.dealer.hand)
# Out:
# {'score': 9,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}

# %%
for card in pok.players["Player 1"].hand:
    print(card)
# Out:
# 5 of DIAMONDS
# ACE of SPADES

# %%
pok.calculate_score(pok.players["Player 1"].hand)
# Out:
# {'score': 6,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}

# %%
pok.draw_card("Player 1")

# %%
for card in pok.players["Player 1"].hand:
    print(card)
# Out:
# 5 of DIAMONDS
# ACE of SPADES
# 8 of SPADES

# %%
pok.calculate_score(pok.players["Player 1"].hand)
# Out:
# {'score': 4,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}
