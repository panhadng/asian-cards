# %%
from cards.cards import Deck

deck = Deck()
print(deck)
# Out:
# Deck is shuffled with ID of 7trl1g4m8qj5 and 52 cards remaining.

# %%
card = deck.draw_cards(1)
print(card)
# Out:
# 3 of SPADES

# %%
deck.remaining
# Out:
# 51

# %%
cards = deck.draw_cards(6)
for card in cards:
    print(card)
# Out:
# 9 of CLUBS
# 4 of DIAMONDS
# ACE of CLUBS
# KING of SPADES
# QUEEN of CLUBS
# 4 of SPADES

# %%
cards
# Out:
# [<cards.cards.Card at 0x10a863680>,
#  <cards.cards.Card at 0x10a8636b0>,
#  <cards.cards.Card at 0x10a8636e0>,
#  <cards.cards.Card at 0x10a863710>,
#  <cards.cards.Card at 0x10a863740>,
#  <cards.cards.Card at 0x10a863770>]

# %%
deck.remaining
# Out:
# 45

# %%
from cards.visualize import visualize_cards

visualize_cards(cards, rows=2, cols=3)

# %%
from games.pok.pok import Pok

pok = Pok(num_players=2)
game = pok.start()
game
# Out:
# {'Players': {'Player 1': <games.pok.pok.Player at 0x10c6d9b20>,
#   'Player 2': <games.pok.pok.Player at 0x10c6738c0>},
#  'Dealer': [<cards.cards.Card at 0x10c7acad0>,
#   <cards.cards.Card at 0x10c7aec60>]}

# %%
pok.players
# Out:
# {'Player 1': <games.pok.pok.Player at 0x10c6d9b20>,
#  'Player 2': <games.pok.pok.Player at 0x10c6738c0>}

# %%
pok.dealer

# %%
from cards.visualize import visualize_cards
visualize_cards(game["Dealer"], rows=1, cols=2)

# %%
for card in pok.dealer.hand:
    print(card)
# Out:
# 6 of DIAMONDS
# 2 of DIAMONDS

# %%
from games.pok.pok import calculate_score

calculate_score(pok.dealer.hand)
# Out:
# {'score': 8,
#  'multi': 2,
#  'is_bomb': True,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}

# %%
pok.draw_card("Dealer")

# %%
for card in pok.dealer.hand:
    print(card)
# Out:
# 6 of DIAMONDS
# 2 of DIAMONDS
# ACE of DIAMONDS

# %%
pok.calculate_score(pok.dealer.hand)
# Out:
# {'score': 9,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}

# %%
for card in pok.players["Player 1"].hand:
    print(card)
# Out:
# 5 of DIAMONDS
# ACE of SPADES

# %%
calculate_score(pok.players["Player 1"].hand)
# Out:
# {'score': 3,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}

# %%
pok.draw_card("Player 1")

# %%
for card in pok.players["Player 1"].hand:
    print(card)
# Out:
# 5 of DIAMONDS
# ACE of SPADES
# 8 of SPADES

# %%
calculate_score(pok.players["Player 1"].hand)
# Out:
# {'score': 4,
#  'multi': 1,
#  'is_bomb': False,
#  'is_three_ongs': False,
#  'is_three_of_a_kind': False}
